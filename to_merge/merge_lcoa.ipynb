# %%
import pandas as pd
import os
import glob

# Define the directory containing the CSV files
directory = os.path.join(os.getcwd()#, 'to_merge'
                                                )
print(directory)
# Get a list of all CSV files in the directory
files = glob.glob(os.path.join(directory, '2050_lcoa_global_*long_20231029.csv'))

# Initialize a dictionary to store DataFrames
dfs = {}
files
# Out:
# /Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge
# ['/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_165to170long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_-125to-120long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_20to25long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_115to120long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_-150to-145long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_-85to-80long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_-155to-150long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_40to45long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_145to150long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_-115to-110long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_125to130long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_155to160long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_-165to-160long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_90to95long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_-110to-105long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_105to110long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_75to80long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_-80to-75long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_135to140long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_65to70long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_5to10long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_-20to-15long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_-50to-45long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_-70to-65long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_-120to-115long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_-60to-55long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_45to50long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_-160to-155long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_-95to-90long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_-30to-25long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_25to30long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_60to65long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_-40to-35long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_-65to-60long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_0to5long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_-175to-170long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_120to125long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_-170to-165long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_-45to-40long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_-10to-5long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_-105to-100long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_100to105long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_-130to-125long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_160to165long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_-145to-140long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_-25to-20long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_140to145long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_35to40long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_-135to-130long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_55to60long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_-180to-175long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_80to85long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_-5to0long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_95to100long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_30to35long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_50to55long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_15to20long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_-15to-10long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_150to155long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_-90to-85long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_-35to-30long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_170to175long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_-100to-95long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_110to115long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_-55to-50long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_70to75long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_130to135long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_-75to-70long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_10to15long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_-140to-135long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_85to90long_20231029.csv',
#  '/Users/carlopalazzi/Programming/shipping_sprint/lcoa_model/lcoa-opt/to_merge/2050_lcoa_global_175to180long_20231029.csv']

# %%
# Iterate over the CSV files, read each file, and store it in the dictionary
for file in files:
    df = pd.read_csv(file)
    filename = os.path.basename(file)
    name = filename.split('_')[3]  # Extract the name part from the file name
    dfs[name] = df

dfs.keys()
# Out:
# dict_keys(['165to170long', '-125to-120long', '20to25long', '115to120long', '-150to-145long', '-85to-80long', '-155to-150long', '40to45long', '145to150long', '-115to-110long', '125to130long', '155to160long', '-165to-160long', '90to95long', '-110to-105long', '105to110long', '75to80long', '-80to-75long', '135to140long', '65to70long', '5to10long', '-20to-15long', '-50to-45long', '-70to-65long', '-120to-115long', '-60to-55long', '45to50long', '-160to-155long', '-95to-90long', '-30to-25long', '25to30long', '60to65long', '-40to-35long', '-65to-60long', '0to5long', '-175to-170long', '120to125long', '-170to-165long', '-45to-40long', '-10to-5long', '-105to-100long', '100to105long', '-130to-125long', '160to165long', '-145to-140long', '-25to-20long', '140to145long', '35to40long', '-135to-130long', '55to60long', '-180to-175long', '80to85long', '-5to0long', '95to100long', '30to35long', '50to55long', '15to20long', '-15to-10long', '150to155long', '-90to-85long', '-35to-30long', '170to175long', '-100to-95long', '110to115long', '-55to-50long', '70to75long', '130to135long', '-75to-70long', '10to15long', '-140to-135long', '85to90long', '175to180long'])

# %%
dfs['165to170long']
# Out:
#     Unnamed: 0  Latitude  Longitude Country  Objective           Wind  \
# 0      -65_165       -65        165     NaN        0.0  151597.870916
# 1      -65_166       -65        166     NaN        0.0  151597.870916
# 2      -65_167       -65        167     NaN        0.0  151597.870916
# 3      -65_168       -65        168     NaN        0.0  151597.870916
# 4      -65_169       -65        169     NaN        0.0  151597.870916
# ..         ...       ...        ...     ...        ...            ...
# 650     65_165        65        165  Russia        0.0  205847.486534
# 651     65_166        65        166  Russia        0.0  205847.486534
# 652     65_167        65        167  Russia        0.0  205847.486534
# 653     65_168        65        168  Russia        0.0  205847.486534
# 654     65_169        65        169  Russia        0.0  205847.486534
#
#             Solar  SolarTracking  Grid  RampDummy  ...          HB  \
# 0    2.095734e+07            0.0   0.0        0.0  ...  228.310502
# 1    2.095734e+07            0.0   0.0        0.0  ...  228.310502
# 2    2.095734e+07            0.0   0.0        0.0  ...  228.310502
# 3    2.095734e+07            0.0   0.0        0.0  ...  228.310502
# 4    2.095734e+07            0.0   0.0        0.0  ...  228.310502
# ..            ...            ...   ...        ...  ...         ...
# 650  9.763925e+05            0.0   0.0        0.0  ...  228.310502
# 651  9.763925e+05            0.0   0.0        0.0  ...  228.310502
# 652  9.763925e+05            0.0   0.0        0.0  ...  228.310502
# 653  9.763925e+05            0.0   0.0        0.0  ...  228.310502
# 654  9.763925e+05            0.0   0.0        0.0  ...  228.310502
#
#      BatteryInterfaceIn  BatteryInterfaceOut  HydrogenFuelCell  PenaltyLink  \
# 0           1153.083345          1141.552511         1000000.0    1000000.0
# 1           1153.083345          1141.552511         1000000.0    1000000.0
# 2           1153.083345          1141.552511         1000000.0    1000000.0
# 3           1153.083345          1141.552511         1000000.0    1000000.0
# 4           1153.083345          1141.552511         1000000.0    1000000.0
# ..                  ...                  ...               ...          ...
# 650         1153.083345          1141.552511         1000000.0    1000000.0
# 651         1153.083345          1141.552511         1000000.0    1000000.0
# 652         1153.083345          1141.552511         1000000.0    1000000.0
# 653         1153.083345          1141.552511         1000000.0    1000000.0
# 654         1153.083345          1141.552511         1000000.0    1000000.0
#
#         Ammonia  CompressedH2Store     Battery  AccumulatedPenalty  \
# 0    10000000.0         10000000.0  10000000.0          10000000.0
# 1    10000000.0         10000000.0  10000000.0          10000000.0
# 2    10000000.0         10000000.0  10000000.0          10000000.0
# 3    10000000.0         10000000.0  10000000.0          10000000.0
# 4    10000000.0         10000000.0  10000000.0          10000000.0
# ..          ...                ...         ...                 ...
# 650  10000000.0         10000000.0  10000000.0          10000000.0
# 651  10000000.0         10000000.0  10000000.0          10000000.0
# 652  10000000.0         10000000.0  10000000.0          10000000.0
# 653  10000000.0         10000000.0  10000000.0          10000000.0
# 654  10000000.0         10000000.0  10000000.0          10000000.0
#
#      Hydrogen Storage (t)
# 0           253807.106599
# 1           253807.106599
# 2           253807.106599
# 3           253807.106599
# 4           253807.106599
# ..                    ...
# 650         253807.106599
# 651         253807.106599
# 652         253807.106599
# 653         253807.106599
# 654         253807.106599
#
# [655 rows x 23 columns]

# %%
# Concatenate all DataFrames in the dictionary
data = pd.concat(dfs.values(), ignore_index=True)

# Sort the DataFrame by Increasing Longitude and decreasing Latitude
data.sort_values(by=['Longitude', 'Latitude'], ascending=[True, False], inplace=True)

# Save the concatenated and sorted data to a single CSV file
data.to_csv(os.path.join(directory, '2050_lcoa_global.csv'), index=False)

# %%
# Concatenate the list of DataFrames into one DataFrame
data = pd.concat(dfs, ignore_index=True)

# Sort the DataFrame by Increasing Longitude and decreasing Latitude
data.sort_values(by=['Longitude', 'Latitude'], ascending=[True, False], inplace=True)

# Save the concatenated and sorted data to a single CSV file
data.to_csv(os.path.join(directory, '2050_lcoa_global.csv'), index=False)
data
# Out:
#       Unnamed: 0  Latitude  Longitude Country  Objective           Wind  \
# 33400    65_-180        65       -180  Russia        0.0  554713.613773
# 33395    64_-180        64       -180     NaN        0.0  566794.710109
# 33390    63_-180        63       -180     NaN        0.0  386047.729684
# 33385    62_-180        62       -180     NaN        0.0  548278.248387
# 33380    61_-180        61       -180     NaN        0.0  446511.364331
# ...          ...       ...        ...     ...        ...            ...
# 46529    -61_179       -61        179     NaN        0.0   37781.223319
# 46524    -62_179       -62        179     NaN        0.0   34331.374877
# 46519    -63_179       -63        179     NaN        0.0   35849.150369
# 46514    -64_179       -64        179     NaN        0.0  111408.964903
# 46509    -65_179       -65        179     NaN        0.0  151597.870916
#
#               Solar  SolarTracking  Grid  RampDummy  ...          HB  \
# 33400  3.623373e+06            0.0   0.0        0.0  ...  228.310502
# 33395  4.427859e+07            0.0   0.0        0.0  ...  228.310502
# 33390  5.022030e+07            0.0   0.0        0.0  ...  228.310502
# 33385  9.994526e+06            0.0   0.0        0.0  ...  228.310502
# 33380  1.482307e+07            0.0   0.0        0.0  ...  228.310502
# ...             ...            ...   ...        ...  ...         ...
# 46529  1.167584e+07            0.0   0.0        0.0  ...  228.310502
# 46524  1.556510e+06            0.0   0.0        0.0  ...  263.435195
# 46519  9.563549e+05            0.0   0.0        0.0  ...  228.310502
# 46514  9.597145e+07            0.0   0.0        0.0  ...  228.310502
# 46509  2.095734e+07            0.0   0.0        0.0  ...  228.310502
#
#        BatteryInterfaceIn  BatteryInterfaceOut  HydrogenFuelCell  PenaltyLink  \
# 33400         1153.083345          1141.552511         1000000.0    1000000.0
# 33395         1153.083345          1141.552511         1000000.0    1000000.0
# 33390         1153.083345          1141.552511         1000000.0    1000000.0
# 33385         1153.083345          1141.552511         1000000.0    1000000.0
# 33380         1153.083345          1141.552511         1000000.0    1000000.0
# ...                   ...                  ...               ...          ...
# 46529         1153.083345          1141.552511         1000000.0    1000000.0
# 46524         1153.083345          1141.552511         1000000.0    1000000.0
# 46519         1153.083345          1141.552511         1000000.0    1000000.0
# 46514         1153.083345          1141.552511         1000000.0    1000000.0
# 46509         1153.083345          1141.552511         1000000.0    1000000.0
#
#           Ammonia  CompressedH2Store     Battery  AccumulatedPenalty  \
# 33400  10000000.0         10000000.0  10000000.0          10000000.0
# 33395  10000000.0         10000000.0  10000000.0          10000000.0
# 33390  10000000.0         10000000.0  10000000.0          10000000.0
# 33385  10000000.0         10000000.0  10000000.0          10000000.0
# 33380  10000000.0         10000000.0  10000000.0          10000000.0
# ...           ...                ...         ...                 ...
# 46529  10000000.0         10000000.0  10000000.0          10000000.0
# 46524  10000000.0         10000000.0  10000000.0          10000000.0
# 46519  10000000.0         10000000.0  10000000.0          10000000.0
# 46514  10000000.0         10000000.0  10000000.0          10000000.0
# 46509  10000000.0         10000000.0  10000000.0          10000000.0
#
#        Hydrogen Storage (t)
# 33400         253807.106599
# 33395         253807.106599
# 33390         253807.106599
# 33385         253807.106599
# 33380         253807.106599
# ...                     ...
# 46529         253807.106599
# 46524         253807.106599
# 46519         253807.106599
# 46514         253807.106599
# 46509         253807.106599
#
# [47160 rows x 23 columns]
